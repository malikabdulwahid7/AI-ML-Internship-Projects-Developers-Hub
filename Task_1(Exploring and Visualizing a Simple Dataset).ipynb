# %% [markdown]
# Step 1: Install Required Libraries

# %%
pip install pandas seaborn matplotlib
# Out:
# Requirement already satisfied: pandas in d:\users\hp\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: seaborn in d:\users\hp\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in d:\users\hp\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: numpy>=1.26.0 in d:\users\hp\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\users\hp\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\users\hp\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\users\hp\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\users\hp\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in d:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Step 2: Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Step 3: Load the Dataset

# %%
df = sns.load_dataset('iris')

# %% [markdown]
# Step 4: Inspect the Dataset
#    Shape (rows, columns)

# %%
print("Shape of dataset:", df.shape)
# Out:
# Shape of dataset: (150, 5)

# %% [markdown]
# Column Names

# %%
print("Column names:", df.columns)
# Out:
# Column names: Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# First 5 Rows

# %%
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Step 5: Summary Information
#  Info (data types, null values)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %% [markdown]
# Describe (statistics)

# %%
print(df.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Step 6: Data Visualization
#  1. Scatter Plot (Feature Relationships)

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=df)
plt.title("Sepal Length vs Sepal Width")
plt.show()

# %% [markdown]
# 2. Histograms (Distribution)

# %%
df.hist(figsize=(10,8))
plt.suptitle("Feature Distributions")
plt.show()

# %% [markdown]
# 3. Box Plot (Outliers Detection)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.title("Boxplot for Detecting Outliers")
plt.show()

# %% [markdown]
# Step 7: Optional (Better Visualization - Pairplot )
